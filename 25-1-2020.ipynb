# %% [markdown]
# # CONCEPT: Pandas Package
# 1. Panda is the most popular python library that is used for data analysis.
# 2. We can analyze data in pandas with:
#    series and dataframes.
# ## Series:
# 1. It is one dimensional(1-D) array defined in pandas that can be used to store any data type.

# %%
import pandas as pd
Data = [1, 3, 4, 5, 6, 2, 9]
s = pd.Series(Data)
print(s)
Index =['a','b','c','d','e','f','g']
si = pd.Series(Data, Index)
si
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 5    2
# 6    9
# dtype: int64
# a    1
# b    3
# c    4
# d    5
# e    6
# f    2
# g    9
# dtype: int64

# %%
dictionary ={'a':1,'b':2,'c':3,'d':4}
sd = pd.Series(dictionary)
print(sd)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
Data =[[1,2,3],[4,5,6]]
snd = pd.Series(Data)
print(snd)
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# dtype: object

# %% [markdown]
# # DataFrames
# 1. It is two-diemension(2-D) data structure defined in pandas which consists of rows and columns.
# 2. Here, Data can be:
#    One or more dictionaries
#    One or more series
#    2D-numpy Ndarray

# %%
dict1 ={'a':1, 'b':2, 'c':3, 'd':4}
dict2 ={'a':5, 'b':6, 'c':7, 'd':8,}
data ={"first":dict1,"second":dict2}
a = pd.DataFrame(data)
print(a)
# Out:
#    first  second
# a      1       5
# b      2       6
# c      3       7
# d      4       8

# %%
s1 = pd.Series([1,5,3,7,9])
s2 = pd.Series([1.1,3.5,4.5,2.6,7.2])
s3 = pd.Series(['a','b','c','d','e'])
a = {'first':s1,'second':s2,'third':s3}
dfseries = pd.DataFrame(a)
dfseries
# Out:
#    first  second third
# 0      1     1.1     a
# 1      5     3.5     b
# 2      3     4.5     c
# 3      7     2.6     d
# 4      9     7.2     e

# %%
d1 = [[1,3,5],[7.9,11]]
d2 = [[2,4,8],[1,4,3]]
Data = {'first':d1,'second':d2}
a=pd.DataFrame(Data)
print(a)
# Out:
#        first     second
# 0  [1, 3, 5]  [2, 4, 8]
# 1  [7.9, 11]  [1, 4, 3]

# %%
name =pd.Series(['siri','anusha','amrutha'])
rollno =pd.Series([598,588,565])
a ={'names':name,'rollnos':rollno}
dfSeries =pd.DataFrame(a)
dfSeries
# Out:
#      names  rollnos
# 0     siri      598
# 1   anusha      588
# 2  amrutha      565

# %%
df1 = pd.DataFrame({"Int_Rate":[2,1,2,3],"IND_GDP":[50,45,45,67]},index=[2001,2002,2003,2004])
df2 = pd.DataFrame({"Low_Tier_HPI":})

# %%
df1 = pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],""})
df2 = pd.DataFrame({"HPI"})

# %%
import pandas as pd
df = pd.DataFrame({"Day":[1,2,3,4],"Visitors":[200,100,230,300],"Bounce_Rate":[20,45,60,10]})
df.set_index("Day",inplace= True)
print(df)
# Out:
#      Visitors  Bounce_Rate
# Day
# 1         200           20
# 2         100           45
# 3         230           60
# 4         300           10

# %%
import pandas as pd
df = pd.DataFrame({"Day":[1,2,3,4],"Visitors":[200,100,230,300],"Bounce_Rate":[20,45,60,10]})
df = df.rename(columns={"Visitors":"Users"})
print(df)
# Out:
#    Day  Users  Bounce_Rate
# 0    1    200           20
# 1    2    100           45
# 2    3    230           60
# 3    4    300           10

# %% [markdown]
# # Matplotlib
# 1. Matplotlib is a python 2D plotting

# %%
import matplotlib.pyplot as plt
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_autogen_docstring',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
# ...

# %% [markdown]
# # Types of Plotting in Matplot
# 1. Lines
# 2. Bar Charts
# 3. Scatter Plot
# 4. Pie Chart

# %%
plt.plot([1,2,3,4,5],[2,8,10,12,14])
plt.xlabel('x Axes')
plt.ylabel('y Axes')
plt.title('Line \n Plotting')
plt.show()

# %%
plt.plot([1,4,6,5],[8,9,10,7],'^',color ='y')

# %%
import numpy as np
x = np.linspace(0,2,100)
plt.plot(x,x*1,label ='line',color ='b')
plt.plot(x,x**2,label ='square',color ='g')
plt.plot(x,x**3,label = 'cube',color ='r')
plt.legend()
plt.xlabel('Days')
plt.ylabel('Work')
plt.title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %% [markdown]
# Bar Graph

# %%
plt.bar([3,6,4,9],[1,8,10,14],label ='bar',color ='g')
plt.legend()
plt.xlabel('Days')
plt.ylabel('Hours')
# Out:
# Text(0, 0.5, 'Hours')

# %%
car1 =[1,2,3,4]
car1_km =[80,90,50,60]
car2 =[5,6,7,8]
car2_km =[50,45,100,75]
plt.bar(car1,car1_km,label ='BMW',width =0.5)
plt.bar(car2,car2_km,label ='BENZ',width =0.5)
plt.legend()
plt.xlabel('No of days')
plt.ylabel('km')
plt.title('Car Data')
# Out:
# Text(0.5, 1.0, 'Car Data')

# %% [markdown]
# # Image in Matplotlib

# %%
img = plt.imread("logo.jpg")
plt.imshow(img)

# %%
plt.imshow(img[100:200,200:400])

# %%
a = [22,55,62,45,21,22,34,42,42,4,2,102,95,85]
b = [0,10,20,30,40,50,60,70,80,95]
plt.hist(a,b,rwidth=0.5)
# Out:
# (array([2., 0., 3., 1., 3., 1., 1., 0., 2.]),
#  array([ 0, 10, 20, 30, 40, 50, 60, 70, 80, 95]),
#  <a list of 9 Patch objects>)

# %% [markdown]
#  # 27-01-2020

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Box Plot
# - Min
# - Inter Quartile Range(IQR)
#    - Inter Quartile
#    - Median
#    - Upper Quartile
# - Max

# %%
marks=np.random.randint(0,100,101)
marks
# Out:
# array([ 9, 56, 12, 75, 75, 39, 31, 29, 47, 39, 65, 87, 26, 82, 58, 99, 34,
#        86, 87, 81, 90, 60, 35, 21, 65, 35, 89, 74, 67,  7, 79, 46, 88, 17,
#         6, 40, 73, 21, 24, 75, 39, 65, 96, 28, 34, 99, 38, 52, 30, 66,  9,
#        81, 93, 98, 62, 90, 43,  0, 88, 92, 75, 81, 93, 40, 46, 40, 99, 55,
#        37, 72, 89, 16, 34, 22, 12, 39, 46, 33, 49, 40, 70, 33,  8, 29,  9,
#        14, 64, 83, 21, 39, 93, 23, 49, 94, 84, 51, 36, 77, 69, 94,  0])

# %%
plt.boxplot(marks)
plt.show()

# %% [markdown]
# # Area Plot

# %%
import matplotlib.pyplot as plt
Days = [1,2,3,4]
working =[8,8,5,9]
sleeping = [8,10,11,12]
plt.stackplot(Days,working,sleeping,colors = ['b','g'],labels = ['working','sleeping'])
plt.legend()
plt.title('Area Plot')
plt.show()

# %% [markdown]
# # Pie Chart

# %%
Days = [1,2,3,4]
working =[8,8,5,9]
sleeping = [8,10,11,12]
slices = [4,10,12]
variables = ['Days','working','sleeping']
plt.pie(slices,labels = variables,colors = ['g','b','r'],startangle =90,autopct ='%1.2f%%')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
x=[1,5,3,7,2,8]
y=[12,22,26,19,13,28]
plt.scatter(x,y,color='g')
plt.show()

# %%
print(dir(plt))
# Out:
# ['Annotation', 'Arrow', 'Artist', 'AutoLocator', 'Axes', 'Button', 'Circle', 'Figure', 'FigureCanvasBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'Number', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotTool', 'Text', 'TickHelper', 'Widget', '_INSTALL_FIG_OBSERVER', '_IP_REGISTERED', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_auto_draw_if_interactive', '_autogen_docstring', '_backend_mod', '_get_running_interactive_framework', '_interactive_bk', '_log', '_pylab_helpers', '_setp', '_setup_pyplot_info_docstrings', '_show', '_string_to_bool', 'acorr', 'angle_spectrum', 'annotate', 'arrow', 'autoscale', 'autumn', 'axes', 
# ...

# %%
data['country']=data['country'].replace({"Republic of korea":})
