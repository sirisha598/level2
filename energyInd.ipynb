# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)
data
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                        Afghanistan
# 1           NaN                                            Albania
# 2           NaN                                            Algeria
# 3           NaN                                     American Samoa
# 4           NaN                                            Andorra
# 5           NaN                                             Angola
# 6           NaN                                           Anguilla
# 7           NaN                                Antigua and Barbuda
# 8           NaN                                          Argentina
# 9           NaN                                            Armenia
# 10          NaN                                              Aruba
# 11          NaN                                          Australia
# 12          NaN                                            Austria
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Petajoules', 'Gigajoules',
#        '%'],
#       dtype='object')

# %%
data =data[['Unnamed: 2','Petajoules','Gigajoules','%']]
data
# Out:
#                                             Unnamed: 2 Petajoules Gigajoules  \
# 0                                          Afghanistan        321         10
# 1                                              Albania        102         35
# 2                                              Algeria       1959         51
# 3                                       American Samoa        ...        ...
# 4                                              Andorra          9        121
# 5                                               Angola        642         27
# 6                                             Anguilla          2        136
# 7                                  Antigua and Barbuda          8         84
# 8                                            Argentina       3378         79
# 9                                              Armenia        143         48
# 10                                               Aruba         12        120
# ...

# %%
data.columns=['country','Petajoules','Petajoules','% Renewable']
data
# Out:
#                                                country Petajoules Petajoules  \
# 0                                          Afghanistan        321         10
# 1                                              Albania        102         35
# 2                                              Algeria       1959         51
# 3                                       American Samoa        ...        ...
# 4                                              Andorra          9        121
# 5                                               Angola        642         27
# 6                                             Anguilla          2        136
# 7                                  Antigua and Barbuda          8         84
# 8                                            Argentina       3378         79
# 9                                              Armenia        143         48
# 10                                               Aruba         12        120
# ...

# %%
data.head()
# Out:
#           country Petajoules Petajoules  % Renewable
# 0     Afghanistan        321         10    78.669280
# 1         Albania        102         35   100.000000
# 2         Algeria       1959         51     0.551010
# 3  American Samoa        ...        ...     0.641026
# 4         Andorra          9        121    88.695650

# %%
data.tail(7)
# Out:
#                                 country Petajoules Petajoules  % Renewable
# 220                             Vanuatu          3         10     14.70588
# 221  Venezuela (Bolivarian Republic of)       2871         95     67.83452
# 222                            Viet Nam       2554         28     45.32152
# 223           Wallis and Futuna Islands          0         26      0.00000
# 224                               Yemen        344         13      0.00000
# 225                              Zambia        400         26     99.71467
# 226                            Zimbabwe        480         32     52.53612

# %%
data.columns=['country','Energy Supply','Energy Supply per Capita','% Renewable']
data
# Out:
#                                                country Energy Supply  \
# 0                                          Afghanistan           321
# 1                                              Albania           102
# 2                                              Algeria          1959
# 3                                       American Samoa           ...
# 4                                              Andorra             9
# 5                                               Angola           642
# 6                                             Anguilla             2
# 7                                  Antigua and Barbuda             8
# 8                                            Argentina          3378
# 9                                              Armenia           143
# 10                                               Aruba            12
# 11                                          Australia1          5386
# 12                                             Austria          1391
# ...

# %%
data['country']
# Out:
# 0                                            Afghanistan
# 1                                                Albania
# 2                                                Algeria
# 3                                         American Samoa
# 4                                                Andorra
# 5                                                 Angola
# 6                                               Anguilla
# 7                                    Antigua and Barbuda
# 8                                              Argentina
# 9                                                Armenia
# 10                                                 Aruba
# 11                                            Australia1
# 12                                               Austria
# 13                                            Azerbaijan
# 14                                               Bahamas
# 15                                               Bahrain
# ...

# %%
data['Energy Supply']=data['Energy Supply'].replace('...','NaN')
data
# Out:
# G:\AN\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                country Energy Supply  \
# 0                                          Afghanistan           321
# 1                                              Albania           102
# 2                                              Algeria          1959
# 3                                       American Samoa           NaN
# 4                                              Andorra             9
# 5                                               Angola           642
# 6                                             Anguilla             2
# ...

# %%
data['Energy Supply per Capita']
# Out:
# 0       10
# 1       35
# 2       51
# 3      ...
# 4      121
# 5       27
# 6      136
# 7       84
# 8       79
# 9       48
# 10     120
# 11     231
# 12     164
# 13      60
# 14     118
# 15     425
# 16      10
# 17      69
# 18     120
# 19     210
# 20      39
# 21      16
# 22      88
# 23      83
# 24      32
# 25     213
# 26      70
# 27      39
# 28      59
# 29      85
#       ...
# 197    136
# 198     28
# 199     13
# 200     79
# 201     56
# 202      6
# 203     19
# 204     28
# 205    611
# 206     39
# 207     64
# 208    210
# 209     85
# 210    ...
# 211     12
# 212    107
# 213    300
# 214    124
# 215     20
# 216    286
# 217    ...
# 218     58
# 219     62
# 220     10
# 221     95
# 222     28
# 223     26
# 224     13
# 225     26
# 226     32
# Name: Energy Supply per Capita, Length: 227, dtype: object

# %%
data['% Renewable']
# Out:
# 0       78.669280
# 1      100.000000
# 2        0.551010
# 3        0.641026
# 4       88.695650
# 5       70.909090
# 6        0.000000
# 7        0.000000
# 8       24.064520
# 9       28.236060
# 10      14.870690
# 11      11.810810
# 12      72.452820
# 13       6.384345
# 14       0.000000
# 15       0.000000
# 16       1.966329
# 17       0.000000
# 18       0.463389
# 19       9.959739
# 20      64.690030
# 21       0.000000
# 22       0.000000
# 23     100.000000
# 24      31.477120
# 25       0.000000
# 26      41.464670
# 27       0.131406
# 28      69.648030
# 29       0.000000
#           ...
# 197     57.745480
# 198     11.568270
# 199     99.742920
# 200      4.305189
# 201     26.140470
# 202      0.000000
# 203     80.180180
# 204      0.000000
# 205      0.000000
# 206      3.492547
# 207     28.536690
# 208      0.000000
# 209      0.000000
# 210      0.000000
# 211     68.018180
# 212      8.067312
# 213      0.000000
# 214     10.600470
# 215     31.072840
# ...

# %%
data['Energy Supply']=data['Energy Supply']*1000000
# Out:
# G:\AN\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                       American Samoa
# 4                                              Andorra
# 5                                               Angola
# 6                                             Anguilla
# 7                                  Antigua and Barbuda
# 8                                            Argentina
# 9                                              Armenia
# 10                                               Aruba
# 11                                          Australia1
# 12                                             Austria
# 13                                          Azerbaijan
# 14                                             Bahamas
# 15                                             Bahrain
# ...
